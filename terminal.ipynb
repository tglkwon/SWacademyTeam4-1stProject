# %%
# cartoon GAN clone
from google.colab import drive
drive.mount('/content/drive')
cd /content/drive/MyDrive/models
# !git clone https://github.com/mnicnc404/CartoonGan-tensorflow.git
# Out:
# Mounted at /content/drive
# Cloning into 'CartoonGan-tensorflow'...
# remote: Enumerating objects: 1605, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 1605 (delta 54), reused 47 (delta 47), pack-reused 1545
# Receiving objects: 100% (1605/1605), 345.94 MiB | 29.34 MiB/s, done.
# Resolving deltas: 100% (701/701), done.
# Checking out files: 100% (425/425), done.

# %%
# colab 성능 확인

# gpu
# !nvidia-smi
# cpu
# !head /proc/cpuinfo
# memory
# !head -n 3 /proc/meminfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# MemTotal:       13297228 kB
# MemFree:         9009372 kB
# MemAvailable:   12285668 kB

# %% [markdown]
# # 새 섹션

# %%
# %env PYTHONPATH="$/env/python:/content/gdrive/My Drive/Colab Notebooks"
# Out:
# env: PYTHONPATH="$/env/python:/content/gdrive/My Drive/Colab Notebooks"

# %%
## colab 설정이므로 다시 안돌려도 됩니다.
# my_path = '/content/env'
## Colab Notebooks 안에 my_env 폴더에 패키지 저장
# os.symlink('/content/drive/MyDrive/Colab Notebooks/my env', my_path)
# sys.path.insert(0, my_path)
# my_path = '/content/env'
# !pip install --target=$my_path 패키지
